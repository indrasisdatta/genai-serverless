# %%
import os

from dotenv import load_dotenv
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

load_dotenv()
# Out:
# True

# %%
engine = create_engine(
    os.getenv('DATABASE_URL'),
    pool_size=5,
    max_overflow=10
)

SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)

def get_db():
    db = SessionLocal()
    try:
        yield db
    finally:
        db.close()

# %%
db = SessionLocal

# %%
import json

from sqlalchemy import text

mydb = db()

mydb.execute(
    text("""
    INSERT INTO parent_documents (id, content, metadata) 
    VALUES (:id, :content, :metadata)
    """),
    {
        "id": 1,
        "content": "test",
        "metadata": json.dumps({"session_id": 123})
    }
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 6
#       1 import json
#       3 from sqlalchemy import text
# ----> 6 db.execute(
#       7     text("""
#       8     INSERT INTO parent_documents (id, content, metadata)
#       9     VALUES (:id, :content, :metadata)
#      10     """),
#      11     {
#      12         "id": 1,
#      13         "content": "test",
#      14         "metadata": json.dumps({"session_id": 123})
#      15     }
#      16 )
#
# AttributeError: 'generator' object has no attribute 'execute'
